# %% [markdown]
# Test Markdown
# __우와__

# %%
1+1
# Out:
# 2

# %%
2+5
# Out:
# 7

# %%
4+19
# Out:
# 23

# %% [markdown]
# SLACK TEST 220419 1055

# %%
10+55
# Out:
# 65

# %%
print('이것은 브랜치 JOONYEONG ')
# Out:
# 이것은 브랜치 JOONYEONG

# %%
print('내가 접수하겠다 -HR-')
